# %%
from process_image.utils import io, plot
from process_image.processing import combination, transformation

# %%
image1 = io.read_image('F:/DIO/BOOTCAMP_UNIMED/PROCESSADOR_DE_imagem/process_image/forest_green.jpeg')
image2 = io.read_image('F:/DIO/BOOTCAMP_UNIMED/PROCESSADOR_DE_imagem/process_image/frorest_grey.jpg')

# %%
plot.plot_image(image1)
plot.plot_image(image2)

# %%
result_image = combination.transfer_histogram(image1, image2)
plot.plot_result(image1, image2, result_image)
